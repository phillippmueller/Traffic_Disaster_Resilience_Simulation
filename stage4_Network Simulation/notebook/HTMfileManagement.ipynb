# %%
import pandas as pd
from scipy.spatial import distance
import os
import math

# %%
path = '../data/raw/traffic/N101.traffic.htm'
trafficdata = pd.read_html(path)[2]
trafficdata
# Out:
#                                                   0   \
# 0                                                NaN
# 1                                                NaN
# 2  List of links of N101 (  what is a link  )  Li...
# 3         List of links of N101 (  what is a link  )
# 4                                            Link no
# 5                                                NaN
# 6                                             N101-1
# 7                                                NaN
# 8  *  Traffic survey was not done on the link. It...
# 9                                                NaN
#
#                                                   1   \
# 0  List of links of N101 (  what is a link  )  Li...
# 1                                                NaN
# 2                                                NaN
# 3         List of links of N101 (  what is a link  )
# 4                                               Name
# 5                                                NaN
# 6           Comilla (Balutopa)- Bibirbazar Land Port
# 7                                                NaN
# 8                                                NaN
# 9                                                NaN
#
#                                            2   \
# 0                                         NaN
# 1                                         NaN
# 2                                         NaN
# 3  List of links of N101 (  what is a link  )
# 4                              Start location
# 5                                         LRP
# 6                                        LRPS
# 7                                         NaN
# 8                                         NaN
# 9                                         NaN
#
#                                            3   \
# 0                                         NaN
# 1                                         NaN
# 2                                         NaN
# 3  List of links of N101 (  what is a link  )
# 4                              Start location
# 5                                      Offset
# 6                                           0
# 7                                         NaN
# 8                                         NaN
# 9                                         NaN
#
#                                            4   \
# 0                                         NaN
# 1                                         NaN
# 2                                         NaN
# 3  List of links of N101 (  what is a link  )
# 4                              Start location
# 5                                    Chainage
# 6                                           0
# 7                                         NaN
# 8                                         NaN
# 9                                         NaN
#
#                                            5   \
# 0                                         NaN
# 1                                         NaN
# 2                                         NaN
# 3  List of links of N101 (  what is a link  )
# 4                                End location
# 5                                         LRP
# 6                                        LRPE
# 7                                         NaN
# 8                                         NaN
# 9                                         NaN
#
#                                            6   \
# 0                                         NaN
# 1                                         NaN
# 2                                         NaN
# 3  List of links of N101 (  what is a link  )
# 4                                End location
# 5                                      Offset
# 6                                           0
# 7                                         NaN
# 8                                         NaN
# 9                                         NaN
#
#                                            7   \
# 0                                         NaN
# 1                                         NaN
# 2                                         NaN
# 3  List of links of N101 (  what is a link  )
# 4                                End location
# 5                                    Chainage
# 6                                       6.021
# 7                                         NaN
# 8                                         NaN
# 9                                         NaN
#
#                                            8   \
# 0                                         NaN
# 1                                         NaN
# 2                                         NaN
# 3  List of links of N101 (  what is a link  )
# 4                                      Length
# 5                                        (Km)
# 6                                       6.021
# 7                                         NaN
# 8                                         NaN
# 9                                         NaN
#
#                                            9   ...  \
# 0                                         NaN  ...
# 1                                         NaN  ...
# 2                                         NaN  ...
# 3  List of links of N101 (  what is a link  )  ...
# 4                                Traffic Data  ...
# 5                                 Heavy Truck  ...
# 6                                       231.0  ...
# 7                                         NaN  ...
# 8                                         NaN  ...
# 9                                         NaN  ...
#
#                                            16  \
# 0                                         NaN
# 1                                         NaN
# 2                                         NaN
# 3  List of links of N101 (  what is a link  )
# 4                                Traffic Data
# 5                                         Car
# 6                                       164.0
# 7                                         NaN
# 8                                         NaN
# 9                                         NaN
#
#                                            17  \
# 0                                         NaN
# 1                                         NaN
# 2                                         NaN
# 3  List of links of N101 (  what is a link  )
# 4                                Traffic Data
# 5                               Auto Rickshaw
# 6                                      5450.0
# 7                                         NaN
# 8                                         NaN
# 9                                         NaN
#
#                                            18  \
# 0                                         NaN
# 1                                         NaN
# 2                                         NaN
# 3  List of links of N101 (  what is a link  )
# 4                                Traffic Data
# 5                                 Motor Cycle
# 6                                       621.0
# 7                                         NaN
# 8                                         NaN
# 9                                         NaN
#
#                                            19  \
# 0                                         NaN
# 1                                         NaN
# 2                                         NaN
# 3  List of links of N101 (  what is a link  )
# 4                                Traffic Data
# 5                                    Bi-Cycle
# 6                                       196.0
# 7                                         NaN
# 8                                         NaN
# 9                                         NaN
#
#                                            20  \
# 0                                         NaN
# 1                                         NaN
# 2                                         NaN
# 3  List of links of N101 (  what is a link  )
# 4                                Traffic Data
# 5                              Cycle Rickshaw
# 6                                       413.0
# 7                                         NaN
# 8                                         NaN
# 9                                         NaN
#
#                                            21  \
# 0                                         NaN
# 1                                         NaN
# 2                                         NaN
# 3  List of links of N101 (  what is a link  )
# 4                                Traffic Data
# 5                                        Cart
# 6                                         0.0
# 7                                         NaN
# 8                                         NaN
# 9                                         NaN
#
#                                            22  \
# 0                                         NaN
# 1                                         NaN
# 2                                         NaN
# 3  List of links of N101 (  what is a link  )
# 4                                       Total
# 5                                   Motorized
# 6                                      9099.0
# 7                                         NaN
# 8                                         NaN
# 9                                         NaN
#
#                                            23  \
# 0                                         NaN
# 1                                         NaN
# 2                                         NaN
# 3  List of links of N101 (  what is a link  )
# 4                                       Total
# 5                               Non Motorized
# 6                                       609.0
# 7                                         NaN
# 8                                         NaN
# 9                                         NaN
#
#                                            24  \
# 0                                         NaN
# 1                                         NaN
# 2                                         NaN
# 3  List of links of N101 (  what is a link  )
# 4                                       Total
# 5                                  Total AADT
# 6                                      9708.0
# 7                                         NaN
# 8                                         NaN
# 9                                         NaN
#
#                                            25
# 0                                         NaN
# 1                                         NaN
# 2                                         NaN
# 3  List of links of N101 (  what is a link  )
# 4                                     Traffic
# 5                                      (AADT)
# 6                                      9708.0
# 7                                         NaN
# 8                                         NaN
# 9                                         NaN
#
# [10 rows x 26 columns]

# %%
trafficdata = trafficdata.iloc[4:-3,[0,1,4,5,25]]
trafficdata
# Out:
#         0                                         1               4   \
# 4  Link no                                      Name  Start location
# 5      NaN                                       NaN        Chainage
# 6   N101-1  Comilla (Balutopa)- Bibirbazar Land Port               0
#
#              5        25
# 4  End location  Traffic
# 5           LRP   (AADT)
# 6          LRPE   9708.0

# %%
trafficdata.columns = trafficdata.iloc[0]
trafficdata = trafficdata[2:]
trafficdata
# Out:
# 4 Link no                                      Name Start location  \
# 6  N101-1  Comilla (Balutopa)- Bibirbazar Land Port              0
#
# 4 End location Traffic
# 6         LRPE  9708.0

# %%
trafficdata["Start location"] = trafficdata["Start location"].astype(float)*1000
trafficdata['Traffic'] = trafficdata['Traffic'].astype(float)

trafficdata.head(15)
# Out:
# C:\Users\nachi\AppData\Local\Temp\ipykernel_21856\2928984763.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   trafficdata["Start location"] = trafficdata["Start location"].astype(float)*1000
# C:\Users\nachi\AppData\Local\Temp\ipykernel_21856\2928984763.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   trafficdata['Traffic'] = trafficdata['Traffic'].astype(float)
# 4 Link no                                      Name  Start location  \
# 6  N101-1  Comilla (Balutopa)- Bibirbazar Land Port             0.0
#
# 4 End location  Traffic
# 6         LRPE   9708.0

# %%
closestrow = trafficdata.iloc[[0]]
closestdistance = 1000
closestrow
# Out:
# 4 Link no                                      Name  Start location  \
# 6  N101-1  Comilla (Balutopa)- Bibirbazar Land Port             0.0
#
# 4 End location  Traffic
# 6         LRPE   9708.0
