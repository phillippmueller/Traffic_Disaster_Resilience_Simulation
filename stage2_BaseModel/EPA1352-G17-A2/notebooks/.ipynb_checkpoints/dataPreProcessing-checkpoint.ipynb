# %%
import pandas as pd
import numpy as np
import math
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# Load the Excel file into a Pandas dataframe
road = pd.read_csv('data/_roads3.csv')
bridge=pd.read_excel('data/BMMS_overview.xlsx')

# %%
N1Road=road.loc[road.road=='N1']
N1Bridge=bridge.loc[bridge.road=='N1']

# %%
N1Road.head()
# Out:
#   road  chainage     lrp        lat        lon  gap       type  \
# 0   N1     0.000    LRPS  23.706028  90.443333  NaN     Others
# 1   N1     0.814   LRPSa  23.702917  90.450417  NaN    Culvert
# 2   N1     0.822   LRPSb  23.702778  90.450472  NaN  CrossRoad
# 3   N1     1.000  LRP001  23.702139  90.451972  NaN     KmPost
# 4   N1     2.000  LRP002  23.697889  90.460583  NaN     KmPost
#
#                                                 name
# 0  Start of Road  after Jatrabari Flyover infront...
# 1                                        Box Culvert
# 2                            Intersection with Z1101
# 3                                    Km post missing
# 4                                    Km post missing

# %%
N1Bridge.tail()
# Out:
#       road       km               type  LRPName                  name  length  \
# 19378   N1  426.915  RCC Girder Bridge  LRP423b     Balu Khali Bridge     7.9
# 19379   N1  427.622  RCC Girder Bridge  LRP424a     Wheke Kang Bridge     6.4
# 19380   N1  429.081  RCC Girder Bridge  LRP425c          Tasse Bridge    12.8
# 19381   N1  436.789  RCC Girder Bridge  LRP433b  Naya Bazar(2) Bridge     9.4
# 19382   N1  453.372       Slab Culvert  LRP449f                DONMIA     2.7
#
#       condition  structureNr  \
# 19378         D       120493
# 19379         D       120498
# 19380         D       120507
# 19381         D       120524
# 19382         D       100933
#
#                                                 roadName  chainage  width  \
# 19378  Dhaka (Jatrabari)-Comilla (Mainamati)-Chittago...   426.915    NaN
# 19379  Dhaka (Jatrabari)-Comilla (Mainamati)-Chittago...   427.622    NaN
# 19380  Dhaka (Jatrabari)-Comilla (Mainamati)-Chittago...   429.081    NaN
# 19381  Dhaka (Jatrabari)-Comilla (Mainamati)-Chittago...   436.789    NaN
# 19382  Dhaka (Jatrabari)-Comilla (Mainamati)-Chittago...   453.372   11.2
#
#        constructionYear  spans        zone      circle     division  \
# 19378               NaN    NaN  Chittagong  Chittagong  Cox's Bazar
# 19379               NaN    NaN  Chittagong  Chittagong  Cox's Bazar
# 19380               NaN    NaN  Chittagong  Chittagong  Cox's Bazar
# 19381               NaN    NaN  Chittagong  Chittagong  Cox's Bazar
# 19382            1972.0    1.0  Chittagong  Chittagong  Cox's Bazar
#
#           sub-division        lat        lon EstimatedLoc
# 19378  Cox's Bazar - 2  21.129768  92.187047  interpolate
# 19379  Cox's Bazar - 2  21.125104  92.191367  interpolate
# 19380  Cox's Bazar - 2  21.114558  92.198021  interpolate
# 19381  Cox's Bazar - 2  21.056294  92.226645  interpolate
# 19382  Cox's Bazar - 2  20.925389  92.264945  interpolate

# %%
N1Bridge = N1Bridge[["road", "LRPName", "condition", "length", "chainage", "lat", "lon", 'name', 'km','constructionYear']]

# %%
sns.set_style('darkgrid')
ax= plt.subplots()

ax=sns.scatterplot(x='lat', y='lon', data=N1Road,color='r')
ax=sns.scatterplot(x='lat', y='lon', data=N1Bridge,color='b')

plt.show()

# %%
highList=pd.unique(N1Road.road)

# %%
lrpRoad=pd.unique(N1Road.lrp)
lrpBridge=pd.unique(N1Bridge.LRPName)
count=0
missing=[]
for i in lrpBridge:
	if i in lrpRoad:
		count+=1
	else:
		missing.append(i)
print('Number of Coinciding bridges and Road LRPs is : '+str(count))
print('Number of Bridges is : '+str(len(lrpBridge)))
print('Number of Roads is : '+str(len(lrpRoad)))
print('Number of bridges without road LRPs : '+str(len(lrpBridge)-count))
#missing
# Out:
# Number of Coinciding bridges and Road LRPs is : 415
# Number of Bridges is : 639
# Number of Roads is : 1339
# Number of bridges without road LRPs : 224

# %%
N1Bridge['Duplicated'] =N1Bridge.duplicated(subset=['LRPName'])
N1Road['Duplicated']=N1Road.duplicated(subset=['lrp'])
# Out:
# C:\Users\nachi\AppData\Local\Temp\ipykernel_8868\1726588904.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   N1Road['Duplicated']=N1Road.duplicated(subset=['lrp'])

# %%
doubles=[]
for i in N1Bridge.index:
    if N1Bridge.loc[i,'Duplicated'] ==True:
        doubles.append(N1Bridge.loc[i,'LRPName'])
#doubles

# %%
given_value = 'LRP021c'

# find the index of the given value
idx = N1Bridge[N1Bridge['LRPName'] == given_value].index[0]

# print the two values above and below the given value
print(N1Bridge.iloc[max(idx-2, 0):idx+3])
# Out:
#    road  LRPName condition  length  chainage        lat        lon  \
# 15   N1  LRP018c         A   25.50    18.093  23.649754  90.584549
# 16   N1  LRP020a         A    6.00    19.760  23.637954  90.593667
# 17   N1  LRP021c         A   86.92    21.184  23.628467  90.602302
# 18   N1  LRP021d         A   89.75    21.184  23.628467  90.602302
# 19   N1  LRP021c         A   89.20    21.184  23.628467  90.602302
#
#                     name      km  constructionYear  Duplicated
# 15    Sonakhal Bridge(L)  18.093               NaN       False
# 16  KRIBORDI BOX CULVERT  19.760            2001.0       False
# 17   Marikhali Bridge(L)  21.184               NaN       False
# 18   Marikhali Bridge(R)  21.184               NaN       False
# 19      MARIKHALL BRIDGE  21.184            2000.0        True

# %%
venn=[]
for i in missing:
    if i in doubles:
        venn.append(i)

# %%
len(venn)
# Out:
# 54

# %%
N1Road["chainage"] = N1Road["chainage"].astype(float)
N1Road["length"] = N1Road["chainage"]*1000 # 20.11680
# Out:
# C:\Users\nachi\AppData\Local\Temp\ipykernel_8868\2594605936.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   N1Road["chainage"] = N1Road["chainage"].astype(float)
# C:\Users\nachi\AppData\Local\Temp\ipykernel_8868\2594605936.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   N1Road["length"] = N1Road["chainage"]*1000 # 20.11680

# %%
for i in range((len(N1Road["length"])-1),0,-1):
    N1Road.loc[i,"length"] = N1Road.loc[i,"length"]-N1Road.loc[i-1,"length"]

# %%
BridgeN1 = N1Bridge.loc[(N1Bridge["chainage"] < 241)]
BridgeN1 = BridgeN1.reset_index(drop=True)

# %%
temp=[]
for i in range(1,len(BridgeN1["road"])):
    if len(BridgeN1["name"][i]) > 4:
        #temp.append(BridgesN1['name'])     #to see the names of the bridges and identify right and left side and how they occur
        if BridgeN1["name"][i][-2:] == 'L)' or BridgeN1["name"][i][-4:] == 'eft)' or BridgeN1["name"][i][-3:] == 'L )' or BridgeN1["name"][i][-4:] == 'EFT)':
            #print(BridgesN1['name'][i][-3:])        #tinker with the last bracket to see the end of the names
            BridgeN1 = BridgeN1.drop(i,axis = 0)

# %%
BridgeN1.shape
# Out:
# (240, 11)

# %%
BridgeN1 = BridgeN1.sort_values(by=['road','km','constructionYear'], ascending=False) 
BridgeN1 = BridgeN1.drop_duplicates(subset=['road', 'km'], keep='first')

# %%
BridgeN1.shape
# Out:
# (210, 11)

# %%
BridgeN1 = BridgeN1.rename(columns={"LRPName": "lrp"})

# %%
N1 = pd.merge(N1Road, BridgeN1, how="outer", on=["road", "lrp", "length", "lat", "lon", "chainage"])

# %%
N1.head()
# Out:
#   road  chainage     lrp        lat        lon  gap       type  \
# 0   N1     0.000    LRPS  23.706028  90.443333  NaN     Others
# 1   N1     0.814   LRPSa  23.702917  90.450417  NaN    Culvert
# 2   N1     0.822   LRPSb  23.702778  90.450472  NaN  CrossRoad
# 3   N1     1.000  LRP001  23.702139  90.451972  NaN     KmPost
# 4   N1     2.000  LRP002  23.697889  90.460583  NaN     KmPost
#
#                                               name_x Duplicated_x  length  \
# 0  Start of Road  after Jatrabari Flyover infront...        False     0.0
# 1                                        Box Culvert        False   814.0
# 2                            Intersection with Z1101        False     8.0
# 3                                    Km post missing        False   178.0
# 4                                    Km post missing        False  1000.0
#
#   condition name_y  km  constructionYear Duplicated_y
# 0       NaN    NaN NaN               NaN          NaN
# 1       NaN    NaN NaN               NaN          NaN
# 2       NaN    NaN NaN               NaN          NaN
# 3       NaN    NaN NaN               NaN          NaN
# 4       NaN    NaN NaN               NaN          NaN

# %%
# add type of road/bridge
N1["model_type"] = N1["lrp"].apply(lambda x: "sink" if x == "LRPS" else ("source" if x == "LRPE" else "link"))
N1.loc[N1["condition"].notnull(), "model_type"] = "bridge"

# %%
N1 = N1.sort_values(by=['road','chainage'],ascending = False)

# %%
N1 = N1[2:]
N1 = N1.reset_index(drop=True)

# %%
N1.loc[0,"model_type"] = "source"

# %%
N1["bridge_name"] = N1["name_y"]
N1["name_y"] = N1["model_type"]

# %%
N1["id"] = range(len(N1))

# %%
N1.head()
# Out:
#   road  chainage      lrp        lat        lon  gap     type  \
# 0   N1   461.946  LRP466c  20.864667  92.298194   BE   Bridge
# 1   N1   461.904  LRP466b  20.865028  92.298250   BS   Bridge
# 2   N1   461.476  LRP466a  20.868860  92.298222  NaN  Culvert
# 3   N1   461.426   LRP466  20.869277  92.298139  NaN   KmPost
# 4   N1   460.632  LRP465b  20.876499  92.297889   BE   Bridge
#
#             name_x Duplicated_x  length condition  name_y  km  \
# 0       Bridge end        False    42.0       NaN  source NaN
# 1     Bridge start        False   428.0       NaN    link NaN
# 2      Box culvert        False    50.0       NaN    link NaN
# 3  Km post missing        False   794.0       NaN    link NaN
# 4       Bridge end        False    43.0       NaN    link NaN
#
#    constructionYear Duplicated_y model_type bridge_name  id
# 0               NaN          NaN     source         NaN   0
# 1               NaN          NaN       link         NaN   1
# 2               NaN          NaN       link         NaN   2
# 3               NaN          NaN       link         NaN   3
# 4               NaN          NaN       link         NaN   4

# %%
N1 = N1[["road", "id", "model_type", "name_y", "lat", "lon", "length", "condition", "bridge_name"]]

# %%
N1 = N1.rename(columns={"name_y": "name"})

# %%
N1[N1["road"] == "N1"].to_csv("data/N1merge.csv", index=None)

# %%
N1Road=road.loc[road.road=='N1']

# %%
N1Road["chainage"] = N1Road["chainage"].astype(float)
N1Road["length"] = N1Road["chainage"]*1000 # 20.11680
# Out:
# C:\Users\nachi\AppData\Local\Temp\ipykernel_8868\2594605936.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   N1Road["chainage"] = N1Road["chainage"].astype(float)
# C:\Users\nachi\AppData\Local\Temp\ipykernel_8868\2594605936.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   N1Road["length"] = N1Road["chainage"]*1000 # 20.11680

# %%
for i in range((len(N1Road["length"])-1),0,-1):
    N1Road.loc[i,"length"] = N1Road.loc[i,"length"]-N1Road.loc[i-1,"length"]

# %%
N1Road.head()
# Out:
#   road  chainage     lrp        lat        lon  gap       type  \
# 0   N1     0.000    LRPS  23.706028  90.443333  NaN     Others
# 1   N1     0.814   LRPSa  23.702917  90.450417  NaN    Culvert
# 2   N1     0.822   LRPSb  23.702778  90.450472  NaN  CrossRoad
# 3   N1     1.000  LRP001  23.702139  90.451972  NaN     KmPost
# 4   N1     2.000  LRP002  23.697889  90.460583  NaN     KmPost
#
#                                                 name  length
# 0  Start of Road  after Jatrabari Flyover infront...     0.0
# 1                                        Box Culvert   814.0
# 2                            Intersection with Z1101     8.0
# 3                                    Km post missing   178.0
# 4                                    Km post missing  1000.0

# %%
N1Road['id'] = N1Road.index
N1Road['model_type'] = 'link'
N1Road.loc[N1Road['gap'] == 'BS', 'model_type'] = 'bridge'
# Out:
# C:\Users\nachi\AppData\Local\Temp\ipykernel_8868\282623045.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   N1Road['id'] = N1Road.index
# C:\Users\nachi\AppData\Local\Temp\ipykernel_8868\282623045.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   N1Road['model_type'] = 'link'

# %%
N1Road.head(16)
# Out:
#    road  chainage      lrp        lat        lon  gap            type  \
# 0    N1     0.000     LRPS  23.706028  90.443333  NaN          Others
# 1    N1     0.814    LRPSa  23.702917  90.450417  NaN         Culvert
# 2    N1     0.822    LRPSb  23.702778  90.450472  NaN       CrossRoad
# 3    N1     1.000   LRP001  23.702139  90.451972  NaN          KmPost
# 4    N1     2.000   LRP002  23.697889  90.460583  NaN          KmPost
# 5    N1     2.130  LRP002a  23.697361  90.461667  NaN         Culvert
# 6    N1     3.000   LRP003  23.693833  90.469138  NaN          KmPost
# 7    N1     4.000   LRP004  23.693611  90.478777  NaN          KmPost
# 8    N1     4.175  LRP004a  23.693805  90.480527  NaN  SideRoad,Right
# 9    N1     5.000   LRP005  23.694750  90.488500  NaN          KmPost
# 10   N1     6.000   LRP006  23.695916  90.498194  NaN          KmPost
# 11   N1     7.000   LRP007  23.697333  90.507750  NaN          KmPost
# 12   N1     7.181  LRP007a  23.697916  90.509278  NaN       CrossRoad
# 13   N1     8.000   LRP008  23.702056  90.515722  NaN          KmPost
# 14   N1     8.011  LRP008a  23.702111  90.515778   BS          Bridge
# 15   N1     8.429  LRP008b  23.704583  90.518833   BE          Bridge
#
#                                                  name  length  id model_type
# 0   Start of Road  after Jatrabari Flyover infront...     0.0   0       link
# 1                                         Box Culvert   814.0   1       link
# 2                             Intersection with Z1101     8.0   2       link
# 3                                     Km post missing   178.0   3       link
# 4                                     Km post missing  1000.0   4       link
# 5                                         Box culvert   130.0   5       link
# 6                                     Km post missing   870.0   6       link
# 7                                     Km post missing  1000.0   7       link
# 8                           Road to Narayanganj(R111)   175.0   8       link
# 9                                     Km post missing   825.0   9       link
# 10                                    Km post missing  1000.0  10       link
# 11                                    Km post missing  1000.0  11       link
# 12           R110,Left to Demra, Right to Narayanganj   181.0  12       link
# 13                                    Km post missing   819.0  13       link
# 14                                     Kachpur bridge    11.0  14     bridge
# 15                                         Bridge end   418.0  15       link

# %%
N1Road=N1Road[["road","lrp", "id", "model_type", "name", "lat", "lon", "length"]]

# %%
N1Road=N1Road[["road", "id", "model_type", "name", "lat", "lon", "length"]]

# %%
N1Road.tail()
# Out:
#      road    id model_type                                               name  \
# 1334   N1  1334       link                                        Box culvert
# 1335   N1  1335     bridge                                       Bridge start
# 1336   N1  1336       link                                         Bridge end
# 1337   N1  1337       link                                      Infor.missing
# 1338   N1  1338       link  End of Road at Shapla Chattar ,Teknaf Meet wit...
#
#             lat        lon  length
# 1334  20.868860  92.298222    50.0
# 1335  20.865028  92.298250   428.0
# 1336  20.864667  92.298194    42.0
# 1337  20.862972  92.298083   178.0
# 1338  20.862917  92.298083   130.0

# %%
N1Road.loc[0,"model_type"] = "sink"
N1Road.loc[1338,"model_type"] = "source"
N1Road.head()
# Out:
#   road  id model_type                                               name  \
# 0   N1   0       sink  Start of Road  after Jatrabari Flyover infront...
# 1   N1   1       link                                        Box Culvert
# 2   N1   2       link                            Intersection with Z1101
# 3   N1   3       link                                    Km post missing
# 4   N1   4       link                                    Km post missing
#
#          lat        lon  length
# 0  23.706028  90.443333     0.0
# 1  23.702917  90.450417   814.0
# 2  23.702778  90.450472     8.0
# 3  23.702139  90.451972   178.0
# 4  23.697889  90.460583  1000.0

# %%
N1Road = N1Road.sort_values(by=['road','id'],ascending = False)
N1Road = N1Road.reset_index(drop=True)
N1Road['id'] = N1Road.index

# %%
N1Road.head()
# Out:
#   road  id model_type                                               name  \
# 0   N1   0     source  End of Road at Shapla Chattar ,Teknaf Meet wit...
# 1   N1   1       link                                      Infor.missing
# 2   N1   2       link                                         Bridge end
# 3   N1   3     bridge                                       Bridge start
# 4   N1   4       link                                        Box culvert
#
#          lat        lon  length
# 0  20.862917  92.298083   130.0
# 1  20.862972  92.298083   178.0
# 2  20.864667  92.298194    42.0
# 3  20.865028  92.298250   428.0
# 4  20.868860  92.298222    50.0

# %%
N1Road[N1Road["road"] == "N1"].to_csv("data/N1.csv", index=None)

# %%
subset=N1Road[N1Road["model_type"] == "bridge"]

# %%
subset.reset_index(drop=True)
# Out:
#     road    id model_type                 name        lat        lon  length
# 0     N1     3     bridge         Bridge start  20.865028  92.298250   428.0
# 1     N1     7     bridge         Bridge start  20.876860  92.297889   163.0
# 2     N1    13     bridge         Bridge start  20.888916  92.298250   742.0
# 3     N1    16     bridge         Bridge start  20.891916  92.291666   171.0
# 4     N1    21     bridge         Bridge start  20.894083  92.288777   103.0
# ..   ...   ...        ...                  ...        ...        ...     ...
# 146   N1  1297     bridge         Bridge start  23.654056  90.577277   352.0
# 147   N1  1299     bridge         Bridge start  23.655972  90.574333   307.0
# 148   N1  1302     bridge  Langalbandhu bridge  23.659111  90.569722   307.0
# 149   N1  1312     bridge         Bridge start  23.691111  90.544889   248.0
# 150   N1  1324     bridge       Kachpur bridge  23.702111  90.515778    11.0
#
# [151 rows x 7 columns]

# %%
latList=pd.unique(subset.lat)
lonList=pd.unique(subset.lon)

# %%
for lat in latList:
    #print(type(lat))
    if lat in N1Bridge.lat:
        print(lat)

# %%
print(N1Bridge.lat)
# Out:
# 0        23.698739
# 1        23.694664
# 2        23.705060
# 3        23.694391
# 4        23.694302
#            ...
# 19378    21.129768
# 19379    21.125104
# 19380    21.114558
# 19381    21.056294
# 19382    20.925389
# Name: lat, Length: 787, dtype: float64
